# %%
# Titanic Exploratory Data Analysis (EDA)

## Project Objective

The objective of this project is to analyze the Titanic dataset using Exploratory Data Analysis (EDA). The analysis aims to understand passenger demographics, identify survival patterns, detect missing values, visualize important relationships, and derive meaningful insights from the data.

## Tools Used

- Python
- Jupyter Notebook
- Pandas
- NumPy
- Matplotlib
- Seaborn
